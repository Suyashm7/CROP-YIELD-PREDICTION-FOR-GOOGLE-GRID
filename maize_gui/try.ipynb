# %%
import pandas as pd
import os

# Folder paths
input_folder = "data\Predictions"        # Folder with original files
output_folder = "data\Parquet_Predictions"     # Folder where parquet files will be saved

# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Loop through all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(".csv"):
        file_path = os.path.join(input_folder, filename)
        
        # Read the file into a DataFrame
        df = pd.read_csv(file_path)
        
        df['yield'] = df['Predicted_Yield']
        df.drop(columns=['Predicted_Yield'], inplace=True)

        
        # Set output path and change extension to .parquet
        output_file = os.path.splitext(filename)[0] + ".parquet"
        output_path = os.path.join(output_folder, output_file)
        
        # Save as Parquet
        df.to_parquet(output_path, engine="pyarrow", index=False)

        print(f"Converted {filename} to {output_file}")
# Out:
# Converted Argentina_predicted.csv to Argentina_predicted.parquet
# Converted Brazil_predicted.csv to Brazil_predicted.parquet
# Converted India_predicted.csv to India_predicted.parquet
# Converted Mexico_predicted.csv to Mexico_predicted.parquet
# Converted South_Africa_predicted.csv to South_Africa_predicted.parquet
# Converted Ukraine_predicted.csv to Ukraine_predicted.parquet
# Converted United_States_predicted.csv to United_States_predicted.parquet

# %%
import pandas as pd

df = pd.read_parquet("./data/Parquet_Predictions/United_States_predicted.parquet")

# Filter rows where Day == 239
df_filtered = df[df['Day'] == 239]

# Compute mean yield for the country
mean_yield = df_filtered['Predicted_Yield'].mean()

print("Mean yield on Day 239:", mean_yield)
# Out:
# Mean yield on Day 239: 6.601844391710472
